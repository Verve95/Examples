# %% [markdown]
# # Исследование надёжности заёмщиков

# %% [markdown]
# Изучим данные, которые переданы для работы над анализом.

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd

# %% [markdown]
# Прочитаем файл *data.csv* и сохраним его в переменной *df*.

# %%
df = pd.read_csv('/datasets/data.csv')

# %% [markdown]
# Общая информация о данных таблицы *df*.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Рассмотрим полученную информацию подробнее.
#
# Всего в таблице 12 столбцов, тип данных у столбцов - *float64*, *int64*, *object*.
#
# Подробно разберём, какие в df столбцы и какую информацию они содержат:
#
# * children — количество детей в семье
# * days_employed — трудовой стаж в днях
# * dob_years — возраст клиента в годах
# * education — образование клиента
# * education_id — идентификатор образования
# * family_status — семейное положение
# * family_status_id — идентификатор семейного положения
# * gender — пол клиента
# * income_type — тип занятости
# * debt — имел ли задолженность по возврату кредитов
# * total_income — доход в месяц
# * purpose — цель получения кредита

# %% [markdown]
# # Переработка данных

# %% [markdown]
# Исключим пропуски, переименуем столбцы, а также проверим данные на наличие дубликатов.

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %% [markdown]
# В названиях столбцов нету пробелов или же ошибок, с данными можно работать корректно.

# %% [markdown]
# Проверим данные на наличие пропусков вызовом набора методов для суммирования пропущенных значений.

# %%
df.isnull().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# Пустые значения свидетельствуют, что для некоторых данных доступна не вся информация. Причины могут быть разные: скажем, не указана информация, либо же сама запись не корректна.

# %% [markdown]
# В столбцах *df['days_employed']* и *df['total_income']* мы видим NaN, не целочисленные данные, а так же отрицательные значения.

# %%
df['days_employed']
# Out:
# 0         -8437.673028
# 1         -4024.803754
# 2         -5623.422610
# 3         -4124.747207
# 4        340266.072047
# 5          -926.185831
# 6         -2879.202052
# 7          -152.779569
# 8         -6929.865299
# 9         -2188.756445
# 10        -4171.483647
# 11         -792.701887
# 12                 NaN
# 13        -1846.641941
# 14        -1844.956182
# 15         -972.364419
# 16        -1719.934226
# 17        -2369.999720
# 18       400281.136913
# 19       -10038.818549
# 20        -1311.604166
# 21         -253.685166
# 22        -1766.644138
# 23         -272.981385
# 24       338551.952911
# 25       363548.489348
# 26                 NaN
# 27         -529.191635
# 28         -717.274324
# 29                 NaN
#              ...
# 21495              NaN
# 21496      -759.680851
# 21497              NaN
# 21498     -1330.627998
# 21499     -9929.015065
# 21500      -578.082757
# 21501    334343.096304
# 21502              NaN
# 21503     -3096.881131
# 21504    355235.728158
# 21505    338904.866406
# 21506     -1556.249906
# 21507       -79.832064
# 21508    386497.714078
# 21509    362161.054124
# 21510              NaN
# 21511      -612.569129
# 21512      -165.377752
# 21513     -1166.216789
# 21514      -280.469996
# 21515      -467.685130
# 21516      -914.391429
# 21517      -404.679034
# 21518    373995.710838
# 21519     -2351.431934
# 21520     -4529.316663
# 21521    343937.404131
# 21522     -2113.346888
# 21523     -3112.481705
# 21524     -1984.507589
# Name: days_employed, Length: 21525, dtype: float64

# %% [markdown]
# Так как пустые значения в таблице находятся в столбцах *days_employed — трудовой стаж в днях* и *total_income — доход в месяц*, то заменяем пропущенные значения в *days_employed — трудовой стаж в днях* на *mean()* всего столбца, а *total_income — доход в месяц*, на *median()* всего столбца. После этой операции нужно убедиться, что таблица больше не содержит пропусков.

# %%
df['days_employed'] = df['days_employed'].fillna(value = df['days_employed'].mean())
# <замена пропущенных значений в столбце 'days_employed' на среднее значение столбца>

# %%
df['total_income'] = df['total_income'].fillna(value = df['total_income'].median())
# <замена пропущенных значений в столбце 'total_income' на медиану столбца>

# %%
df.isnull().sum()
# <проверка на отсутствие>
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# Получение первых 5 строк таблицы.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# Получение последних 5 строк таблицы.

# %%
df.tail(5)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 21520         1   -4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1   -2113.346888         38   среднее             1
# 21523         3   -3112.481705         38   среднее             1
# 21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля

# %% [markdown]
# Посмотрим список уникальных значений столбца *education*, так как в данном столбце видно, что одне и те же значения разным размером штрифта.

# %%
df['education'].unique()
# Out:
# array(['высшее', 'среднее', 'Среднее', 'СРЕДНЕЕ', 'ВЫСШЕЕ',
#        'неоконченное высшее', 'начальное', 'Высшее',
#        'НЕОКОНЧЕННОЕ ВЫСШЕЕ', 'Неоконченное высшее', 'НАЧАЛЬНОЕ',
#        'Начальное', 'Ученая степень', 'УЧЕНАЯ СТЕПЕНЬ', 'ученая степень'],
#       dtype=object)

# %% [markdown]
# Группируем данные по образованию и вызовом метода *count()* подсчитываем должности к образованию.

# %%
df.groupby('education')['income_type'].count()
# <группировка данных таблицы df по столбцу 'education' и подсчёт количества значений столбца 'income_type'>
# Out:
# education
# ВЫСШЕЕ                   274
# Высшее                   268
# НАЧАЛЬНОЕ                 17
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# Начальное                 15
# Неоконченное высшее       47
# СРЕДНЕЕ                  772
# Среднее                  711
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# высшее                  4718
# начальное                250
# неоконченное высшее      668
# среднее                13750
# ученая степень             4
# Name: income_type, dtype: int64

# %% [markdown]
# Видим, что в таблице попадаются дубликаты, переведём их в нижний регистр через *lower()*.

# %%
df['education'] = df['education'].str.lower()

# %% [markdown]
# Сделаем повторный пересчёт столбца *education*, видим, что данные перераспределились по значениям с нижним регистром, теперь у нас остались только уникальные значения.

# %%
df.groupby('education')['income_type'].count()
# Out:
# education
# высшее                  5260
# начальное                282
# неоконченное высшее      744
# среднее                15233
# ученая степень             6
# Name: income_type, dtype: int64

# %% [markdown]
# Чтобы убедиться, что значения теперь корректно отображаются, выведим первые 5 строк.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %% [markdown]
# Столбцы *df['days_employed']*, *df['total_income']* состоят из типа данных *float64*, переведём его в *int64* для удобства просчёта.

# %%
df['days_employed'] = df['days_employed'].astype('int')

# %%
df['total_income'] = df['total_income'].astype('int')

# %% [markdown]
# Выведим информацию о таблице и убедимся, что тип данных сменился на *int64*.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null int64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null int64
# purpose             21525 non-null object
# dtypes: int64(7), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Проверим столбец, сгрупируем и посмотрим присутсвуют ли в нем ошибки или некорректные данные.

# %%
df.groupby('children')['income_type'].count()
# Out:
# children
# -1        47
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  4        41
#  5         9
#  20       76
# Name: income_type, dtype: int64

# %% [markdown]
# Мы нашли отрацательное значения (-1), а так же то, что у 76 человек в поле дети, указано колличество 20, что вызывает сомнения в достоверности данных, так что перепроверим и выведим часть данных этого значения.

# %% [markdown]
# Для начала переведём через *abs()* значение (-1) в положительное (1), так как скорее всего была допущена ошибка при заполнения столбца.

# %%
df['children'] = df['children'].abs()

# %% [markdown]
# Так же поступим и со столбцом *df['days_employed']*, так как в данном столбце указаны как отрицательные, так и положительные данные, но он отвечает за "трудовой стаж работы в днях", поэтому скорее всего, что так же была допущена ошибка, так как данный показатель может быть или 0 или же иметь положительное значение.

# %%
df['days_employed'] = df['days_employed'].abs()

# %% [markdown]
# Вернёмся к категории у которой числится 20 детей, посмотрим, что указывают другие столбцы о данной категории.

# %%
df.loc[df['children'] == 20]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 606          20            880         21              среднее             1
# 720          20            855         44              среднее             1
# 1074         20           3310         56              среднее             1
# 2510         20           2714         59               высшее             0
# 2941         20           2161          0              среднее             1
# 3302         20          63046         35              среднее             1
# 3396         20          63046         56               высшее             0
# 3671         20            913         23              среднее             1
# 3697         20           2907         40              среднее             1
# 3735         20            805         26               высшее             0
# 3877         20           8190         45              среднее             1
# 5020         20            231         37              среднее             1
# 5315         20           2047         24              среднее             1
# 5349         20         361744         64              среднее             1
# 5362         20         355898         69              среднее             1
# 6198         20          63046         35               высшее             0
# 6428         20           8545         46              среднее             1
# 7027         20            690         54              среднее             1
# 7078         20           1202         40              среднее             1
# 7516         20            893         45              среднее             1
# 7789         20         360485         55              среднее             1
# 7962         20            323         40               высшее             0
# 8430         20          63046         60              среднее             1
# 8883         20           4749         36              среднее             1
# 8909         20           1749         41              среднее             1
# 8950         20           4511         32              среднее             1
# 9889         20           2232         34              среднее             1
# 10194        20           6557         42               высшее             0
# 10377        20           2634         49               высшее             0
# 10736        20           4378         30               высшее             0
# ...         ...            ...        ...                  ...           ...
# 13618        20         338097         49              среднее             1
# 14355        20         378510         56              среднее             1
# 14474        20           2625         27              среднее             1
# 14782        20            233         50              среднее             1
# 15313        20            133         56              среднее             1
# 15674        20           5419         33              среднее             1
# 15762        20           4744         41              среднее             1
# 15812        20           3438         42              среднее             1
# 15976        20          63046         39              среднее             1
# 16371        20            419         29  неоконченное высшее             2
# 16795        20           2530         29              среднее             1
# 16886        20            957         33               высшее             0
# 17093        20           1481         42              среднее             1
# 17134        20           1399         46              среднее             1
# 17286        20          63046         50               высшее             0
# 17509        20            461         31              среднее             1
# 18476        20           4686         36              среднее             1
# 18493        20            121         49              среднее             1
# 18756        20           2334         51              среднее             1
# 18890        20            904         37              среднее             1
# 19271        20            325         43               высшее             0
# 19562        20            721         30  неоконченное высшее             2
# 19774        20          63046         59              среднее             1
# 20038        20            782         32              среднее             1
# 20355        20           2695         45              среднее             1
# 21008        20           1240         40              среднее             1
# 21325        20            601         37              среднее             1
# 21390        20          63046         53              среднее             1
# 21404        20            494         52              среднее             1
# 21491        20            173         27              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 606          женат / замужем                 0      M    компаньон     0
# 720          женат / замужем                 0      F    компаньон     0
# 1074         женат / замужем                 0      F    сотрудник     1
# 2510          вдовец / вдова                 2      F    сотрудник     0
# 2941         женат / замужем                 0      F    сотрудник     0
# 3302   Не женат / не замужем                 4      F  госслужащий     0
# 3396         женат / замужем                 0      F    компаньон     0
# 3671   Не женат / не замужем                 4      F    сотрудник     0
# 3697        гражданский брак                 1      M    сотрудник     0
# 3735   Не женат / не замужем                 4      M    сотрудник     0
# 3877        гражданский брак                 1      F    сотрудник     0
# 5020        гражданский брак                 1      M    компаньон     0
# 5315         женат / замужем                 0      F    сотрудник     0
# 5349          вдовец / вдова                 2      F    пенсионер     0
# 5362         женат / замужем                 0      M    пенсионер     0
# 6198   Не женат / не замужем                 4      M    компаньон     0
# 6428        гражданский брак                 1      F    сотрудник     0
# 7027        гражданский брак                 1      F    компаньон     0
# 7078         женат / замужем                 0      F    сотрудник     0
# 7516         женат / замужем                 0      F    сотрудник     0
# 7789         женат / замужем                 0      F    пенсионер     0
# 7962         женат / замужем                 0      M    компаньон     0
# 8430          вдовец / вдова                 2      F    пенсионер     0
# 8883         женат / замужем                 0      M    сотрудник     0
# 8909         женат / замужем                 0      M    сотрудник     0
# 8950         женат / замужем                 0      M    сотрудник     0
# 9889   Не женат / не замужем                 4      M    сотрудник     0
# 10194        женат / замужем                 0      M    сотрудник     0
# 10377        женат / замужем                 0      F    сотрудник     0
# 10736        женат / замужем                 0      F    компаньон     0
# ...                      ...               ...    ...          ...   ...
# 13618        женат / замужем                 0      F    пенсионер     0
# 14355        женат / замужем                 0      F    пенсионер     0
# 14474        женат / замужем                 0      F    сотрудник     0
# 14782        женат / замужем                 0      M    компаньон     0
# 15313        женат / замужем                 0      F    компаньон     0
# 15674       гражданский брак                 1      F    сотрудник     0
# 15762        женат / замужем                 0      F    сотрудник     0
# 15812        женат / замужем                 0      F    сотрудник     0
# 15976  Не женат / не замужем                 4      F    сотрудник     0
# 16371  Не женат / не замужем                 4      M    сотрудник     0
# 16795        женат / замужем                 0      M    компаньон     0
# 16886        женат / замужем                 0      F    сотрудник     0
# 17093        женат / замужем                 0      F    сотрудник     0
# 17134        женат / замужем                 0      M    компаньон     0
# 17286              в разводе                 3      F    сотрудник     0
# 17509  Не женат / не замужем                 4      F    сотрудник     0
# 18476        женат / замужем                 0      M  госслужащий     0
# 18493        женат / замужем                 0      F    компаньон     0
# 18756        женат / замужем                 0      F    сотрудник     0
# 18890        женат / замужем                 0      F    компаньон     1
# 19271        женат / замужем                 0      M    сотрудник     0
# 19562       гражданский брак                 1      F    компаньон     0
# 19774       гражданский брак                 1      F    пенсионер     0
# 20038  Не женат / не замужем                 4      M    сотрудник     1
# 20355       гражданский брак                 1      M    сотрудник     1
# 21008        женат / замужем                 0      F    сотрудник     1
# 21325        женат / замужем                 0      F    компаньон     0
# 21390        женат / замужем                 0      M    компаньон     0
# 21404        женат / замужем                 0      M    компаньон     0
# 21491        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                 purpose
# 606          145334                           покупка жилья
# 720          112998                    покупка недвижимости
# 1074         229518                   получение образования
# 2510         264474   операции с коммерческой недвижимостью
# 2941         199739                   на покупку автомобиля
# 3302         145017                  профильное образование
# 3396         145017                      высшее образование
# 3671         101255      на покупку подержанного автомобиля
# 3697         115380      на покупку подержанного автомобиля
# 3735         137200                            ремонт жилью
# 3877         312270        сделка с подержанным автомобилем
# 5020         260203                         сыграть свадьбу
# 5315         100415       покупка коммерческой недвижимости
# 5349          81926                       операции с жильем
# 5362         138579                              автомобили
# 6198         145017                                   жилье
# 6428         145733                         сыграть свадьбу
# 7027         100206                   на проведение свадьбы
# 7078          67529           получение высшего образования
# 7516         113956                 покупка жилья для сдачи
# 7789         138626  строительство собственной недвижимости
# 7962         190051  строительство собственной недвижимости
# 8430         145017                           покупка жилья
# 8883         441721                      высшее образование
# 8909         200383                            ремонт жилью
# 8950         300682      на покупку подержанного автомобиля
# 9889          53971                           покупка жилья
# 10194        124621                             образование
# 10377         67794                       операции с жильем
# 10736        154706                      высшее образование
# ...             ...                                     ...
# 13618        140616  строительство собственной недвижимости
# 14355        127947        сделка с подержанным автомобилем
# 14474        244092                      высшее образование
# 14782        215296        сделка с подержанным автомобилем
# 15313        299339                      высшее образование
# 15674        155567                                 свадьба
# 15762        143529              дополнительное образование
# 15812        295265                                   жилье
# 15976        145017                    покупка недвижимости
# 16371        122062   операции с коммерческой недвижимостью
# 16795         95454                            недвижимость
# 16886         86656        сделка с подержанным автомобилем
# 17093         73069   получение дополнительного образования
# 17134        136446                 покупка жилья для семьи
# 17286        145017       покупка коммерческой недвижимости
# 17509         90937                                   жилье
# 18476        258005      на покупку подержанного автомобиля
# 18493        306808  строительство собственной недвижимости
# 18756        224637                              автомобиль
# 18890        212811      на покупку подержанного автомобиля
# 19271        272626                         свой автомобиль
# 19562        133319                         сыграть свадьбу
# 19774        145017                         сыграть свадьбу
# 20038        117758       покупка коммерческой недвижимости
# 20355        177922                   на проведение свадьбы
# 21008        133524                         свой автомобиль
# 21325        102986                  профильное образование
# 21390        145017              покупка жилой недвижимости
# 21404        156629         операции со своей недвижимостью
# 21491        155520      на покупку подержанного автомобиля
#
# [76 rows x 12 columns]

# %% [markdown]
# Видим, что есть те, кто "не женат/не замужем" и в возрасте 23 года завёл более 20-ти детей, вызывает сомнения данная категория. Скорее всего, либо опечатка, либо ошибка в выгрузке данных, и так как данные сомнения падают на 76 строчек, а это меньше 1% от общего количества, то заменим 20, на 2х детей.

# %%
df['children'] = df['children'].replace(20, 2)

# %% [markdown]
# Повторно выведим данные, сгрупировав значения и подсчитаем. Как видим в данном случае данные отправились в стобец к заёмщикам с 2-мя детьми.

# %%
df.groupby('children')['income_type'].count()
# Out:
# children
# 0    14149
# 1     4865
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: income_type, dtype: int64

# %% [markdown]
# Необходимо установить наличие дубликатов.  Если найдутся, удаляем, и проверяем, все ли удалились.

# %%
df.duplicated().sum()
# <получение суммарного количества дубликатов в таблице df>
# Out:
# 71

# %%
df = df.drop_duplicates().reset_index(drop=True)
# <удаление всех дубликатов из таблицы df специальным методом>

# %%
df.duplicated().sum()
# <проверка на отсутствие>
# Out:
# 0

# %% [markdown]
# Дубликаты могли появиться вследствие сбоя в записи данных, либо при выгрузке из системы.

# %% [markdown]
# Проверим, есть ли в столбцах *df['days_employed']*, *df['total_income']* на некорректиные строки.

# %%
count_lines = 0
total_position = 0
wrong_lines = 0
for row in df['total_income']:
    try:
        count_lines += 1
        level = row
        total_position += level
    except:
        wrong_lines += 1
print('Количество измерений', count_lines)    
print('Количество некорректных строк', wrong_lines)
# Out:
# Количество измерений 21454
# Количество некорректных строк 0

# %%
count_lines = 0
total_position = 0
wrong_lines = 0
for row in df['days_employed']:
    try:
        count_lines += 1
        level = row
        total_position += level
    except:
        wrong_lines += 1
print('Количество измерений', count_lines)    
print('Количество некорректных строк', wrong_lines)
# Out:
# Количество измерений 21454
# Количество некорректных строк 0

# %% [markdown]
# Получаем общую информацию о данных. Убеждаемся, что чистка выполнена успешно.

# %%
df.info()
# <получение общей информации о данных таблицы df>
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21454 entries, 0 to 21453
# Data columns (total 12 columns):
# children            21454 non-null int64
# days_employed       21454 non-null int64
# dob_years           21454 non-null int64
# education           21454 non-null object
# education_id        21454 non-null int64
# family_status       21454 non-null object
# family_status_id    21454 non-null int64
# gender              21454 non-null object
# income_type         21454 non-null object
# debt                21454 non-null int64
# total_income        21454 non-null int64
# purpose             21454 non-null object
# dtypes: int64(7), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Так как в столбце *purpose — цель получения кредита* цели записаны в разной форме, необходимо провести леммматизацию и так как в данные указаны на русском языке, будет удобно и актуально использовать библиотеку *pymystem3*.

# %% [markdown]
# Импортируем библиотеку и лемматизируем столбец *purpose*, вызвав функцию *lemmas*.

# %%
from pymystem3 import Mystem
m = Mystem()

def lemmas(purpose):
    lemma = m.lemmatize(purpose)
    return lemma

# %% [markdown]
# Выведим и добавим результат лемматизации столбца, добавив столбец *lemm_purpose*.

# %%
df['lemm_purpose'] = df['purpose'].apply(lemmas)

# %% [markdown]
# Проверим результат, получив первых 5 строк таблицы.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                          lemm_purpose
# 0               покупка жилья               [покупка,  , жилье, \n]
# 1     приобретение автомобиля     [приобретение,  , автомобиль, \n]
# 2               покупка жилья               [покупка,  , жилье, \n]
# 3  дополнительное образование  [дополнительный,  , образование, \n]
# 4             сыграть свадьбу             [сыграть,  , свадьба, \n]

# %% [markdown]
# Сощдадим функцию *lemm_category()*,которая будет принимать значения столбца(лемму) и возвращать категорию прнадлежности, после категоризируем данные столбца *lemm_purpose*, чтобы можно было определить тип цели получения кредита.

# %%
def lemm_category(rows):
   
    if 'автомобиль' in rows:
        return 'автомобиль'
    if 'свадьба' in rows:
        return 'свадьба'
    if  'жилье' and 'ремонт' in rows:
        return 'ремонт жилья'
    if  'жилье' in rows:
        return 'жилье'
    if 'недвижимость' in rows:
        return 'недвижимость'   
    if 'образование' in rows:
        return 'образование'

# %% [markdown]
# Выполнив функцию, добавим её результат в столбец *lemm_category*.

# %%
df['lemm_category'] = df['lemm_purpose'].apply(lemm_category)

# %% [markdown]
# Проверим результат, получив первых 5 строк таблицы, посморим на новый столбец и соответсвует ли он функции.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                          lemm_purpose  \
# 0               покупка жилья               [покупка,  , жилье, \n]
# 1     приобретение автомобиля     [приобретение,  , автомобиль, \n]
# 2               покупка жилья               [покупка,  , жилье, \n]
# 3  дополнительное образование  [дополнительный,  , образование, \n]
# 4             сыграть свадьбу             [сыграть,  , свадьба, \n]
#
#   lemm_category
# 0         жилье
# 1    автомобиль
# 2         жилье
# 3   образование
# 4       свадьба

# %% [markdown]
# Проверим сходятся ли наши значения и сохранены ли везле типы данных.

# %% [markdown]
# Рассмотрим, на какие цели чаще всего берут кредит.

# %%
df.groupby('lemm_category')['purpose'].count()
# Out:
# lemm_category
# автомобиль      4306
# жилье           3853
# недвижимость    6351
# образование     4013
# ремонт жилья     607
# свадьба         2324
# Name: purpose, dtype: int64

# %%
df.info()
# <получение общей информации о данных таблицы df>
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21454 entries, 0 to 21453
# Data columns (total 14 columns):
# children            21454 non-null int64
# days_employed       21454 non-null int64
# dob_years           21454 non-null int64
# education           21454 non-null object
# education_id        21454 non-null int64
# family_status       21454 non-null object
# family_status_id    21454 non-null int64
# gender              21454 non-null object
# income_type         21454 non-null object
# debt                21454 non-null int64
# total_income        21454 non-null int64
# purpose             21454 non-null object
# lemm_purpose        21454 non-null object
# lemm_category       21454 non-null object
# dtypes: int64(7), object(7)
# memory usage: 2.3+ MB

# %% [markdown]
# Создадим функцию income(), которая будет принимать уровень дохода и возраващать индификатор, в зависимости от суммы.

# %%
def income(income_value):
    if income_value < 50000:
        return 1
    if 50000 < income_value <= 100000:
        return 2
    if 100000 < income_value <= 150000:
        return 3
    if 150000 < income_value <= 200000:
        return 4
    if 200000 < income_value <= 250000:
        return 5
    if income_value > 250000:
        return 6

# %% [markdown]
# Выполнив функцию, добавим её результат в столбец *income_type_id*.

# %%
df['income_type_id'] = df['total_income'].apply(income)

# %% [markdown]
# Проверим результат, получив первых 5 строк таблицы, посморим на новый столбец и соответсвует ли он функции.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                          lemm_purpose  \
# 0               покупка жилья               [покупка,  , жилье, \n]
# 1     приобретение автомобиля     [приобретение,  , автомобиль, \n]
# 2               покупка жилья               [покупка,  , жилье, \n]
# 3  дополнительное образование  [дополнительный,  , образование, \n]
# 4             сыграть свадьбу             [сыграть,  , свадьба, \n]
#
#   lemm_category  income_type_id
# 0         жилье               6
# 1    автомобиль               3
# 2         жилье               3
# 3   образование               6
# 4       свадьба               4

# %% [markdown]
# Проверим работу функции, как видим функция работает корректно и верно распределяет *id*.

# %%
income(120000)
# Out:
# 3

# %% [markdown]
# Создадим функцию *income_name()*, которая будет принимать индификатор уровня дохода и возраващать пренадлежность, в зависимости от индификатора.

# %%
def income_name(income_id):
    if income_id == 1:
        return 'Доход меньше 50 тыс'
    if income_id == 2:
        return 'Доход 50-100 тыс'
    if income_id == 3:
        return 'Доход 100-150 тыс'
    if income_id == 4:
        return 'Доход 150-200 тыс'
    if income_id == 5:
        return 'Доход 200-250 тыс'
    if income_id == 6:
        return 'Доход больше 250 тыс'

# %% [markdown]
# Выполнив функцию, добавим её результат в столбец *income_sort*.

# %%
df['income_sort'] = df['income_type_id'].apply(income_name)

# %% [markdown]
# Проверим результат, получив первых 5 строк таблицы, посморим на новый столбец и соответсвует ли он функции.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                          lemm_purpose  \
# 0               покупка жилья               [покупка,  , жилье, \n]
# 1     приобретение автомобиля     [приобретение,  , автомобиль, \n]
# 2               покупка жилья               [покупка,  , жилье, \n]
# 3  дополнительное образование  [дополнительный,  , образование, \n]
# 4             сыграть свадьбу             [сыграть,  , свадьба, \n]
#
#   lemm_category  income_type_id           income_sort
# 0         жилье               6  Доход больше 250 тыс
# 1    автомобиль               3     Доход 100-150 тыс
# 2         жилье               3     Доход 100-150 тыс
# 3   образование               6  Доход больше 250 тыс
# 4       свадьба               4     Доход 150-200 тыс

# %% [markdown]
# Проверим работу функции, как видим функция работает корректно и верно определяет *income_sort*.

# %%
income_name(3)
# Out:
# 'Доход 100-150 тыс'

# %% [markdown]
# Создадим функцию *children_name()*, которая будет принимать количество детей и возраващать пренадлежность, в зависимости от количества.

# %%
def children_name(children_id):
    if children_id == 0:
        return 'Без детей'
    if children_id == 1:
        return 'Один ребёнок'
    if children_id == 2:
        return 'Двое детей'
    if children_id == 3:
        return 'Трое детей'
    if children_id == 4:
        return 'Четверо детей'
    if children_id == 5:
        return 'Пятеро детей'

# %% [markdown]
# Выполнив функцию, добавим её результат в столбец *children_sort*.

# %%
df['children_sort'] = df['children'].apply(children_name)

# %% [markdown]
# Проверим работу функции, как видим функция работает корректно и верно определяет *children_sort*.

# %%
children_name(3)
# Out:
# 'Трое детей'

# %% [markdown]
# Проверим результат, получив первых 5 строк таблицы, посморим на новый столбец и соответсвует ли он функции.

# %%
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                          lemm_purpose  \
# 0               покупка жилья               [покупка,  , жилье, \n]
# 1     приобретение автомобиля     [приобретение,  , автомобиль, \n]
# 2               покупка жилья               [покупка,  , жилье, \n]
# 3  дополнительное образование  [дополнительный,  , образование, \n]
# 4             сыграть свадьбу             [сыграть,  , свадьба, \n]
#
#   lemm_category  income_type_id           income_sort children_sort
# 0         жилье               6  Доход больше 250 тыс  Один ребёнок
# 1    автомобиль               3     Доход 100-150 тыс  Один ребёнок
# 2         жилье               3     Доход 100-150 тыс     Без детей
# 3   образование               6  Доход больше 250 тыс    Трое детей
# 4       свадьба               4     Доход 150-200 тыс     Без детей

# %% [markdown]
# # Анализ полученных данных

# %% [markdown]
# Посмотрим, с каким доходом и какой целью кредита, чаще всего встречаются проблемы с выплатою в срок.

# %%
money = df.pivot_table(index = 'income_sort' , columns = 'lemm_category', values = 'debt', aggfunc = 'sum')

# %% [markdown]
# Отсортируем сводную таблицу.

# %%
money.sort_values(by = 'income_sort', ascending = False)
# Out:
# lemm_category         автомобиль  жилье  недвижимость  образование  \
# income_sort
# Доход меньше 50 тыс           10      2             6            2
# Доход больше 250 тыс          48     31            53           42
# Доход 50-100 тыс              62     51            94           79
# Доход 200-250 тыс             38     24            58           29
# Доход 150-200 тыс             83     60           106           76
# Доход 100-150 тыс            162    105           157          142
#
# lemm_category         ремонт жилья  свадьба
# income_sort
# Доход меньше 50 тыс              0        3
# Доход больше 250 тыс             5       15
# Доход 50-100 тыс                 4       41
# Доход 200-250 тыс                2       13
# Доход 150-200 тыс               12       31
# Доход 100-150 тыс               12       83

# %% [markdown]
# Как видно, самым проблематичным кредитом является цель связанная с автомобилем и недвижимостью, что ещё более интересно то, что довольно много просрочек у заёмщиков с доходом свыше 150 тыс.

# %% [markdown]
# Рассмотрим, как разные цели кредита влияют на его возврат в срок?

# %%
lemm_debt = df.pivot_table(index = 'lemm_category', values = 'debt', aggfunc='sum')

# %% [markdown]
# Отсортируем сводную таблицу по убыванию.

# %%
lemm_debt.sort_values(by = 'debt', ascending = False)
# Out:
#                debt
# lemm_category
# недвижимость    474
# автомобиль      403
# образование     370
# жилье           273
# свадьба         186
# ремонт жилья     35

# %% [markdown]
# Вывод таков, самыми "проблематичными" можно считать цели на "недвижимость" и "автомобиль", они возварщаются чаще всего не в нужный срок.

# %% [markdown]
# Рассмотрим, *есть ли зависимость между наличием детей и возвратом кредита в срок?*

# %%
child_debt = df.pivot_table(index = 'children_sort', values = 'debt', aggfunc='sum')

# %% [markdown]
# Отсортируем сводную таблицу по убыванию.

# %%
child_debt.sort_values(by = 'debt', ascending = False)
# Out:
#                debt
# children_sort
# Без детей      1063
# Один ребёнок    445
# Двое детей      202
# Трое детей       27
# Четверо детей     4
# Пятеро детей      0

# %% [markdown]
# Вывод таков, заёмщики, которые без детей или с одним ребёнком чаще всего возвращают кредит не в назначенный срок.

# %% [markdown]
# В строке *пятеро детей* отсутствуют задолженности, проверим с чем это связанно. Проверим сколько вовсе данных заёмщиков.

# %%
df.loc[df['children_sort'] == 'Пятеро детей']['children_sort'].count()
# Out:
# 9

# %% [markdown]
# В данном случае, заёмщиков из пятерью детьми, только лишь 9, можно предлоположить, что данная категория очень редко обращаются за получением кредита.

# %% [markdown]
# Рассмотрим, *есть ли зависимость между семейным положением и возвратом кредита в срок?*

# %%
family_debt = df.pivot_table(index = 'family_status', values = 'debt', aggfunc='sum')

# %% [markdown]
# Отсортируем сводную таблицу по убыванию.

# %%
family_debt.sort_values(by = 'debt', ascending = False)
# Out:
#                        debt
# family_status
# женат / замужем         931
# гражданский брак        388
# Не женат / не замужем   274
# в разводе                85
# вдовец / вдова           63

# %% [markdown]
# Рассмотрим, *есть ли зависимость между уровнем дохода и возвратом кредита в срок?*

# %%
income_sort_debt = df.pivot_table(index = 'income_sort', values = 'debt', aggfunc='sum')

# %% [markdown]
# Отсортируем сводную таблицу по убыванию.

# %%
income_sort_debt.sort_values(by = 'debt', ascending = False)
# Out:
#                       debt
# income_sort
# Доход 100-150 тыс      661
# Доход 150-200 тыс      368
# Доход 50-100 тыс       331
# Доход больше 250 тыс   194
# Доход 200-250 тыс      164
# Доход меньше 50 тыс     23

# %% [markdown]
# Вывод таков, со всех категорий дохода чаще всего заёмщики, с доходом от 100 - 200 тыс, возвращают кредит не во время.

# %% [markdown]
# # Результаты исследования

# %% [markdown]
# Рабочие гипотизы и что удалось обнаружить:
#
# * Чаще всего целью кредита являются: недвижимость/жилье, автомобиль и образование;
# * Цели, которые чаще других не выплачиваются вовремя являются: недвижимость и автомобиль;
# * Заёмщики без детей чаще других не выплачивали кредит вовремя;
# * Клиенты, которые были женаты/замужем чаще других не выплачивали кредит вовремя;
# * Клиенты, с доходом 100-150 тыс чаще других не выплачивали кредит вовремя;
#
# Общие результаты таковы, что на не вовремя выплаченный кредит влиет почти каждый фактор, начиная от количества детей, заканчивая целью кредита, мы проанализировали и дали ответ на основные вопросы (находится выше), так к примеру если и заёмщика доход около 70 тыс, это не значит, что он не сможет выплатить вовремя взятый кредит, так что не стоит опираться лишь на один из факторов, а подходить комплексно, изучая больше аспектов и важных факторов клиента.
